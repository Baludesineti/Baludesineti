# %% [markdown]
# <a href="https://colab.research.google.com/github/Baludesineti/Baludesineti/blob/main/Cognify_2nd_Railway_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Level 1: Data Exploration and Basic Operations**

# %% [markdown]
# # **Task 1.1: Load and Inspect Data**

# %% [markdown]
# # Load the dataset using appropriate Python libraries

# %%
# Importing Source
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading dataset
df =pd.read_csv("/content/Railway_info.csv")
df
# Out:
#        Train_No    Train_Name Source_Station_Name  \
# 0           107  SWV-MAO-VLNK     SAWANTWADI ROAD
# 1           108  VLNK-MAO-SWV         MADGOAN JN.
# 2           128  MAO-KOP SPEC         MADGOAN JN.
# 3           290  PALACE ON WH   DELHI-SAFDAR JANG
# 4           401  BSB BHARATDA          AURANGABAD
# ...         ...           ...                 ...
# 11108     99904  PUNE-TGN EMU            PUNE JN.
# 11109     99905           EMU            TALEGAON
# 11110     99906           EMU            PUNE JN.
# 11111     99907           EMU            TALEGAON
# 11112     99908           EMU            PUNE JN.
#
#                  Destination_Station_Name       days
# 0                             MADGOAN JN.   Saturday
# 1                         SAWANTWADI ROAD     Friday
# 2      CHHATRAPATI SHAHU MAHARAJ TERMINUS     Friday
# 3                       DELHI-SAFDAR JANG  Wednesday
# 4                            VARANASI JN.   Saturday
# ...

# %% [markdown]
# # Display the first 10 rows of the dataset to get an initial understanding of the data.

# %%
df.head(11)
# Out:
#     Train_No    Train_Name           Source_Station_Name  \
# 0        107  SWV-MAO-VLNK               SAWANTWADI ROAD
# 1        108  VLNK-MAO-SWV                   MADGOAN JN.
# 2        128  MAO-KOP SPEC                   MADGOAN JN.
# 3        290  PALACE ON WH             DELHI-SAFDAR JANG
# 4        401  BSB BHARATDA                    AURANGABAD
# 5        421  LKO-SVDK FTR                   LUCKNOW JN.
# 6        422  SVDK-LKO FTR  SHRI MATA VAISHNO DEVI KATRA
# 7        477  FTR TRAIN NO                         SIRSA
# 8        502  RJPB-UMB FTR        RAJENDRANAGAR TERMINAL
# 9        504  PNBE-BTI FTR                     PATNA JN.
# 10       506  PNBE-PTA FTR                     PATNA JN.
#
#               Destination_Station_Name       days
# 0                          MADGOAN JN.   Saturday
# 1                      SAWANTWADI ROAD     Friday
# 2   CHHATRAPATI SHAHU MAHARAJ TERMINUS     Friday
# 3                    DELHI-SAFDAR JANG  Wednesday
# ...

# %% [markdown]
# # Investigate the basic structure of the dataset by examining data types and identifying any missing values.

# %%
# Find no.if columns and Rows
df.shape
# Out:
# (11113, 5)

# %%
# Getting Columns Names
df.columns
# Out:
# Index(['Train_No', 'Train_Name', 'Source_Station_Name',
#        'Destination_Station_Name', 'days'],
#       dtype='object')

# %%
data_types = df.dtypes
data_types
# Out:
# Train_No                     int64
# Train_Name                  object
# Source_Station_Name         object
# Destination_Station_Name    object
# days                        object
# dtype: object

# %%
# Checking the Missing Values in the dataset
data_missing = df.isnull().sum()
data_missing
# Out:
# Train_No                    0
# Train_Name                  0
# Source_Station_Name         0
# Destination_Station_Name    0
# days                        0
# dtype: int64

# %% [markdown]
# # **Task 1.2: Basic Statistics**

# %% [markdown]
# # Calculate key statistics including:
# # The total number of trains.
# # The count of unique source stations.
# # The count of unique destination stations.

# %%
# Find total trins
len(df['Train_No'].unique())
# Out:
# 11113

# %%
# Count Unique Source Stations

len(df['Source_Station_Name'].unique())
# Out:
# 921

# %%
# Count Unique Destination Stations
len(df['Destination_Station_Name'].unique())
# Out:
# 924

# %% [markdown]
# # Identify the most common source and destination stations.

# %%
# find most common Source & Destination Stations
df["Source_Station_Name"].value_counts()
# Out:
# Source_Station_Name
# CST-MUMBAI         513
# SEALDAH            372
# CHENNAI BEACH      339
# HOWRAH JN.         338
# KALYAN JN          285
#                   ...
# MANENDRAGARH         1
# LANJI GARH ROAD      1
# FURKATING JN.        1
# TALCHER              1
# KOLAGHAT             1
# Name: count, Length: 921, dtype: int64

# %% [markdown]
# # **Task 1.3: Data Cleaning**

# %% [markdown]
# ## Detects and handles missing values in the dataset to ensure data integrity.

# %%
# Fill missing values in numerical columns with the mean.
df['Train_No'].fillna(df['Train_No'].mean(), inplace=True)

# %%
# Fill missing values in categorical columns with the most frequent value.
df['Source_Station_Name'].fillna(df['Source_Station_Name'].mode()[0], inplace=True)
df['Destination_Station_Name'].fillna(df['Destination_Station_Name'].mode()[0], inplace=True)

# %%
# Verify if there are still any missing values
remaining_missing = df.isnull().sum()
print(remaining_missing)
# Out:
# Train_No                    0
# Train_Name                  0
# Source_Station_Name         0
# Destination_Station_Name    0
# days                        0
# dtype: int64

# %% [markdown]
# # Standardise the format of station names for consistency, for instance, converting all names to uppercase.

# %%
# Convert station names to uppercase
df['Source_Station_Name'] = df['Source_Station_Name'].str.upper()
df['Destination_Station_Name'] = df['Destination_Station_Name'].str.upper()
df
# Out:
#        Train_No    Train_Name Source_Station_Name  \
# 0           107  SWV-MAO-VLNK     SAWANTWADI ROAD
# 1           108  VLNK-MAO-SWV         MADGOAN JN.
# 2           128  MAO-KOP SPEC         MADGOAN JN.
# 3           290  PALACE ON WH   DELHI-SAFDAR JANG
# 4           401  BSB BHARATDA          AURANGABAD
# ...         ...           ...                 ...
# 11108     99904  PUNE-TGN EMU            PUNE JN.
# 11109     99905           EMU            TALEGAON
# 11110     99906           EMU            PUNE JN.
# 11111     99907           EMU            TALEGAON
# 11112     99908           EMU            PUNE JN.
#
#                  Destination_Station_Name       days
# 0                             MADGOAN JN.   Saturday
# 1                         SAWANTWADI ROAD     Friday
# 2      CHHATRAPATI SHAHU MAHARAJ TERMINUS     Friday
# 3                       DELHI-SAFDAR JANG  Wednesday
# 4                            VARANASI JN.   Saturday
# ...

# %% [markdown]
# # **Level 2: Data Transformation and Aggregation**

# %% [markdown]
# # **Task 2.1: Data Filtering**

# %% [markdown]
# # Filter the dataset to show trains that operate on specific days (e.g., Saturdays).

# %%
train_day = df[df['days'].isin(["Saturday"])]
train_day
# Out:
#        Train_No    Train_Name Source_Station_Name Destination_Station_Name  \
# 0           107  SWV-MAO-VLNK     SAWANTWADI ROAD              MADGOAN JN.
# 4           401  BSB BHARATDA          AURANGABAD             VARANASI JN.
# 21         1196  NGP-KRMI SPL      NAGPUR JN.(CR)                  KARMALI
# 28         1706   JBP-BDTS SF            JABALPUR          BANDRA TERMINUS
# 45         2834  SRC-RJT SF A     SANTRAGACHI JN.                   RAJKOT
# ...         ...           ...                 ...                      ...
# 11084     99816  PUNE-LNL EMU            PUNE JN.                  LONAVLA
# 11086     99818      PUNE-LNL            PUNE JN.                  LONAVLA
# 11094     99826  PUNE-LNL EMU            PUNE JN.                  LONAVLA
# 11100     99832  PUNE-LNL EMU        SHIVAJINAGAR                  LONAVLA
# 11104     99836  PUNE-TGN EMU            PUNE JN.                  LONAVLA
#
#            days
# 0      Saturday
# 4      Saturday
# ...

# %% [markdown]
# # Create a new dataframe containing trains that start from a particular station.

# %%
# Create a new dataframe containing trains that start from a particular station.
start_station = "HOWRAH JN"
trains_from_station = df[df['Source_Station_Name'] == start_station]
print(trains_from_station)
# Out:
# Empty DataFrame
# Columns: [Train_No, Train_Name, Source_Station_Name, Destination_Station_Name, days]
# Index: []

# %% [markdown]
# # **Task 2.2: Grouping and Aggregation**

# %% [markdown]
# # Group the data by source station and compute the number of trains originating from each station.

# %%
# No.Of Trains from each Station
df.groupby('Source_Station_Name')['Train_No'].count()
# Out:
# Source_Station_Name
# ABHANPUR JN.       2
# ABOHAR             1
# ABU ROAD           1
# ACHHNERA JN.       1
# ADILABAD           5
#                   ..
# WARASEONI          1
# WARDHA JN.         4
# WHITE FIELD        2
# YAMUNA BRIDGE      2
# YESVANTPUR JN.    60
# Name: Train_No, Length: 921, dtype: int64

# %% [markdown]
# # Determine the average number of trains per day for each source station.

# %%
# Calculate the average number of trains per day for each source station
average_trains_per_day = df.groupby('Source_Station_Name')['Train_No'].count() / 7
print(average_trains_per_day)
# Out:
# Source_Station_Name
# ABHANPUR JN.      0.285714
# ABOHAR            0.142857
# ABU ROAD          0.142857
# ACHHNERA JN.      0.142857
# ADILABAD          0.714286
#                     ...
# WARASEONI         0.142857
# WARDHA JN.        0.571429
# WHITE FIELD       0.285714
# YAMUNA BRIDGE     0.285714
# YESVANTPUR JN.    8.571429
# Name: Train_No, Length: 921, dtype: float64

# %% [markdown]
# # **Task 2.3: Data Enrichment**

# %% [markdown]
# # Enrich the dataset by adding a new column that categorises trains based on their operating days (e.g., 'Weekday', 'Weekend').

# %%
# Define a function to categorize trains based on operating days
def categorize_train(days):
  if "Saturday" in days or "Sunday" in days:
    return "Weekend"
  else:
    return "Weekday"

# Apply the function to create a new column 'Train_Category'
df['Train_Category'] = df['days'].apply(categorize_train)

# Display the updated DataFrame
print(df)
# Out:
#        Train_No    Train_Name Source_Station_Name  \
# 0           107  SWV-MAO-VLNK     SAWANTWADI ROAD
# 1           108  VLNK-MAO-SWV         MADGOAN JN.
# 2           128  MAO-KOP SPEC         MADGOAN JN.
# 3           290  PALACE ON WH   DELHI-SAFDAR JANG
# 4           401  BSB BHARATDA          AURANGABAD
# ...         ...           ...                 ...
# 11108     99904  PUNE-TGN EMU            PUNE JN.
# 11109     99905           EMU            TALEGAON
# 11110     99906           EMU            PUNE JN.
# 11111     99907           EMU            TALEGAON
# 11112     99908           EMU            PUNE JN.
#
#                  Destination_Station_Name       days Train_Category
# 0                             MADGOAN JN.   Saturday        Weekend
# 1                         SAWANTWADI ROAD     Friday        Weekday
# 2      CHHATRAPATI SHAHU MAHARAJ TERMINUS     Friday        Weekday
# 3                       DELHI-SAFDAR JANG  Wednesday        Weekday
# ...

# %% [markdown]
# # **Level 3: Advanced Data Analysis**

# %% [markdown]
# # **Task 3.1: Pattern Analysis**

# %% [markdown]
# # Analyse the distribution of train journeys throughout the week and visualise the findings using bar plots or histograms.

# %%
# Group the data by day of the week and count the number of trains
trains_per_day = df['days'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
trains_per_day.plot(kind='bar')
plt.title('Distribution of Train Journeys Throughout the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Trains')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Identify and examine patterns or trends in train operations based on source and destination stations.

# %%
# Group by source and destination stations and count the frequency
route_freq = df.groupby(['Source_Station_Name', 'Destination_Station_Name']).size().reset_index(name='frequency')

# Sort by frequency
route_freq = route_freq.sort_values(by='frequency', ascending=False)

# Display the most common routes
print(route_freq.head(10))
# Out:
#      Source_Station_Name Destination_Station_Name  frequency
# 4400            TAMBARAM            CHENNAI BEACH        137
# 928        CHENNAI BEACH                 TAMBARAM        137
# 1127          CST-MUMBAI                   PANVEL         94
# 3490              PANVEL               CST-MUMBAI         93
# 1129          CST-MUMBAI                 RAVLI JN         90
# 3892            RAVLI JN               CST-MUMBAI         90
# 4716          VELACHEERY            CHENNAI BEACH         89
# 932        CHENNAI BEACH               VELACHEERY         87
# 1132          CST-MUMBAI                    THANE         77
# 4443               THANE               CST-MUMBAI         72

# %%
# Visualize the top 10 most common routes
top_routes = route_freq.head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x='frequency', y='Source_Station_Name', hue='Destination_Station_Name', data=top_routes, dodge=False)
plt.title('Top 10 Most Common Train Routes')
plt.xlabel('Frequency')
plt.ylabel('Routes')
plt.show()

# %% [markdown]
# # **Task 3.2: Correlation and Insights**

# %% [markdown]
# # Investigate any correlation between the number of trains and specific days of the week.

# %%
# Create a contingency table of days of the week and train counts
contingency_table = pd.crosstab(df['days'], df['Train_No'])

# Calculate the Chi-squared statistic and p-value
from scipy.stats import chi2_contingency
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results
print("Chi-squared statistic:", chi2)
print("P-value:", p)

# Interpret the results
if p < 0.05:
  print("There is a statistically significant correlation between the number of trains and specific days of the week.")
else:
  print("There is no statistically significant correlation between the number of trains and specific days of the week.")
# Out:
# Chi-squared statistic: 144469.00000000003
# P-value: 0.4898578379750315
# There is no statistically significant correlation between the number of trains and specific days of the week.

# %% [markdown]
# # Develop insights and recommendations based on the analysis to inform decision making.

# %% [markdown]
# # **Insights and Recommendations**
#
# # **1. Peak Travel Days:** The analysis reveals that certain days of the week experience a significantly higher volume of train journeys. This information can be leveraged to:
#
# #   **Optimize Train Schedules:** Increase the frequency of trains on peak days to accommodate the higher demand.
# #   **Dynamic Pricing:** Implement dynamic pricing strategies to adjust ticket prices based on demand, maximizing revenue during peak periods.
#
# # **2. Popular Routes:** Identifying the most popular train routes provides valuable insights for:
#
# #   **Capacity Management:** Allocate resources and increase train capacity on high-demand routes to ensure passenger comfort and convenience.
# #   **Targeted Marketing:** Tailor marketing campaigns to promote specific routes and attract more passengers.
#
# # **3. Station Importance:** Understanding the number of trains originating from each station helps in:
#
# #   **Infrastructure Development:** Prioritize infrastructure upgrades and expansions at stations with high train traffic.
# #   **Resource Allocation:** Efficiently allocate staff and resources based on the volume of train operations at each station.
#
# # **4. Weekend Travel Patterns:** The categorization of trains into 'Weekday' and 'Weekend' categories highlights:
#
# #   **Targeted Services:** Introduce special weekend train services or packages to cater to leisure travelers.
# #   **Promotional Offers:** Offer weekend discounts or promotions to encourage more people to travel by train during weekends.
#
# # **5. Correlation Analysis:** The statistical analysis of the correlation between train frequency and days of the week provides evidence for:
#
# #   **Data-Driven Decision Making:** Utilize the findings to make informed decisions about train scheduling, pricing, and resource allocation.
#
# # **Overall Recommendation:**
#
# # By leveraging these insights, railway authorities can optimize train operations, enhance passenger experiences, and maximize revenue generation.
# # Continuous data analysis and monitoring will further refine strategies and ensure the railway system remains efficient and responsive to passenger needs.

# %% [markdown]
# # **Level 4: Data Visualization and Reporting**

# %% [markdown]
# # **Task 4.1: Visualisation**

# %% [markdown]
# # Create various visualisations (bar charts, line charts, heatmaps) to illustrate different aspects of the data, such as the number of trains per station and day-wise distribution.

# %%
# Bar chart for number of trains per station
plt.figure(figsize=(12, 6))
df['Source_Station_Name'].value_counts().plot(kind='bar')
plt.title('Number of Trains per Station')
plt.xlabel('Station')
plt.ylabel('Number of Trains')
plt.xticks(rotation=90)
plt.show()

# Line chart for day-wise distribution of trains
plt.figure(figsize=(10, 6))
df['days'].value_counts().sort_index().plot(kind='line', marker='o')
plt.title('Day-wise Distribution of Trains')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Trains')
plt.grid(True)
plt.show()

# %% [markdown]
# # Utilise visualisation tools like Matplotlib, Seaborn, or Plotly for creating these visualisations.

# %%
# Bar chart for number of trains per station using Seaborn
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Source_Station_Name', order=df['Source_Station_Name'].value_counts().index)
plt.title('Number of Trains per Station')
plt.xlabel('Station')
plt.ylabel('Number of Trains')
plt.xticks(rotation=90)
plt.show()

# Line chart for day-wise distribution of trains using Plotly
import plotly.express as px
day_counts = df['days'].value_counts().sort_index()
fig = px.line(x=day_counts.index, y=day_counts.values, markers=True)
fig.update_layout(title='Day-wise Distribution of Trains', xaxis_title='Day of the Week', yaxis_title='Number of Trains')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Task 4.2: Reporting**

# %% [markdown]
# # Compile a comprehensive report summarising all findings, visualisations, and insights derived from the data.

# %%
# Analyze the most common source and destination stations
source_station_counts = df['Source_Station_Name'].value_counts()
destination_station_counts = df['Destination_Station_Name'].value_counts()

# Display the top 5 most common source and destination stations
top_source_stations = source_station_counts.head(5)
top_destination_stations = destination_station_counts.head(5)

# Plot the top 5 source stations
plt.figure(figsize=(10, 6))
sns.barplot(x=top_source_stations.values, y=top_source_stations.index, palette="viridis")
plt.title('Top 5 Source Stations')
plt.xlabel('Number of Trains')
plt.ylabel('Source Station')
plt.savefig('top_source_stations.png')
plt.show()
# Out:
# <ipython-input-27-aab02c7c823f>:11: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
# Plot the top 5 destination stations
plt.figure(figsize=(10, 6))
sns.barplot(x=top_destination_stations.values, y=top_destination_stations.index, palette="viridis")
plt.title('Top 5 Destination Stations')
plt.xlabel('Number of Trains')
plt.ylabel('Destination Station')
plt.savefig('top_destination_stations.png')
plt.show()
# Out:
# <ipython-input-28-14d158341594>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
# Clean the 'days' column to remove anomalies
df['days'] = df['days'].str.replace('d', '')

# Analyze the frequency of trains operating on different days
days_counts = df['days'].value_counts()

# Plot the frequency of trains operating on different days
plt.figure(figsize=(10, 6))
sns.barplot(x=days_counts.index, y=days_counts.values, palette="viridis")
plt.title('Frequency of Trains Operating on Different Days')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Trains')
plt.savefig('train_frequency_by_day.png')
plt.show()
# Out:
# <ipython-input-29-fbc3c7fae6b3>:9: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Analyze connectivity between key stations
connectivity_counts = df.groupby(['Source_Station_Name', 'Destination_Station_Name']).size().reset_index(name='train_count')

# Sort the DataFrame by train_count in descending order to get the most common routes
top_connectivity = connectivity_counts.sort_values(by='train_count', ascending=False).head(10)

# Save the top connectivity to a CSV file for the report
top_connectivity.to_csv('top_connectivity.csv', index=False)

# Generate a comprehensive report
report = f"""
# Railway Data Analysis Report

# 1. Top 5 Source Stations
The following are the top 5 source stations based on the number of trains:
{top_source_stations.to_string()}

![Top Source Stations](top_source_stations.png)

# 2. Top 5 Destination Stations
The following are the top 5 destination stations based on the number of trains:
{top_destination_stations.to_string()}

![Top Destination Stations](top_destination_stations.png)

# 3. Frequency of Trains Operating on Different Days
The frequency of trains operating on different days of the week is as follows:
{days_counts.to_string()}



# 4. Top 10 Train Routes

{top_connectivity.to_string(index=False)}

The detailed data can be found in the 'top_connectivity.csv' file.
"""

# %% [markdown]
# # Ensure the report is clear and concise, suitable for presenting to stakeholders.

# %%
# Save the report to a markdown file
with open('Railway_Analysis_Report.md', 'w') as f:
    f.write(report)

print("Comprehensive report generated and saved as 'Railway_Analysis_Report.md'.")
# Out:
# Comprehensive report generated and saved as 'Railway_Analysis_Report.md'.
